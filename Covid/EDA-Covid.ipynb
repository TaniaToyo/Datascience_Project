# %% [markdown]
# # Covid India Dataset
# - Source: Kaggle
# - Data: Till 21st September 2021
# - Use: To understand spread of Covid

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Latest Covid-19 India Status.csv')

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman and Nicobar         7600      13        7458     129
# 1       Andhra Pradesh      2039529   14388     2011063   14078
# 2    Arunachal Pradesh        54126     410       53444     272
# 3                Assam       598423    4984      587632    5807
# 4                Bihar       725901      69      716173    9659
#
#    Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 0              0.17                98.13             1.70
# 1              0.71                98.60             0.69
# 2              0.76                98.74             0.50
# 3              0.83                98.20             0.97
# 4              0.01                98.66             1.33

# %% [markdown]
# ## Data Preparing and Cleaning
# - Columns: 8
# - Rows: 36 (28 states along with 8 union territories)
# - Categorical variables: 1
# - Numerical variables : 7
# - No Null values
# - Active Ratio (%) - Ratio of number of active cases to total cases
# - Discharge Ratio (%) - Ratio of number of discharged cases to total cases
# - Death Ratio (%) - Ratio of number of deaths to total cases

# %%
df.shape
# Out:
# (36, 8)

# %%
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio (%)', 'Discharge Ratio (%)', 'Death Ratio (%)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State/UTs            36 non-null     object
#  1   Total Cases          36 non-null     int64
#  2   Active               36 non-null     int64
#  3   Discharged           36 non-null     int64
#  4   Deaths               36 non-null     int64
#  5   Active Ratio (%)     36 non-null     float64
#  6   Discharge Ratio (%)  36 non-null     float64
#  7   Death Ratio (%)      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
df.isnull().sum()
# Out:
# State/UTs              0
# Total Cases            0
# Active                 0
# Discharged             0
# Deaths                 0
# Active Ratio (%)       0
# Discharge Ratio (%)    0
# Death Ratio (%)        0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.sort_values('Total Cases',ascending=False).head()
# Out:
#          State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 20     Maharashtra      6524498   45229     6340723  138546              0.69
# 16          Kerala      4524158  167578     4332897   23683              3.70
# 15       Karnataka      2968543   14386     2916530   37627              0.48
# 30      Tamil Nadu      2647041   16984     2594697   35360              0.64
# 1   Andhra Pradesh      2039529   14388     2011063   14078              0.71
#
#     Discharge Ratio (%)  Death Ratio (%)
# 20                97.18             2.12
# 16                95.77             0.52
# 15                98.25             1.27
# 30                98.02             1.34
# 1                 98.60             0.69

# %%
df.sort_values('Deaths',ascending=False)
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 20                               Maharashtra      6524498   45229     6340723
# 15                                 Karnataka      2968543   14386     2916530
# 30                                Tamil Nadu      2647041   16984     2594697
# 8                                      Delhi      1438517     379     1413053
# 16                                    Kerala      4524158  167578     4332897
# 33                             Uttar Pradesh      1709680     194     1686599
# 35                               West Bengal      1562173    7810     1535699
# 27                                    Punjab       601323     307      584517
# 1                             Andhra Pradesh      2039529   14388     2011063
# 6                               Chhattisgarh      1005094     297      991234
# 19                            Madhya Pradesh       792402      96      781789
# ...

# %%
# Out:
# 0     17.0
# 1      6.9
# 2      5.0
# 3      9.7
# 4     13.3
# 5     12.5
# 6     13.5
# 7      0.4
# 8     17.4
# 9     18.8
# 10    12.2
# 11    12.7
# 12    16.8
# 13    13.5
# 14    14.7
# 15    12.7
# 16     5.2
# 17    10.0
# 18     4.9
# 19    13.3
# 20    21.2
# 21    15.4
# 22    17.3
# 23     3.2
# 24    21.2
# 25     8.0
# 26    14.6
# 27    27.4
# 28     9.4
# 29    12.3
# 30    13.4
# 31     5.9
# 32     9.6
# 33    13.4
# 34    21.5
# 35    11.9
# Name: Death Ratio (%), dtype: float64

# %%
138546/6524498
# Out:
# 0.02123473713993015

# %% [markdown]
# ## Ask Questions and Answer
# 1. Top 5 states with most cases?

# %% [markdown]
# ## Summary and Conclusion
# - Top 5 states with most cases: Maharashtra, Kerala, Karnataka, Tamil Nadu, Andhara Pradesh
